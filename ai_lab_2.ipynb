# %% [markdown]
# <a href="https://colab.research.google.com/github/abhirampurella/Practical--1-DAA/blob/main/ai_lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICA 1

# %%
print("Hello! I am python.")
print("Today we will build a cleaning robot together.")
print(2 + 3, "is the answer to 2 + 3")
room = ["D", "C", "D", "D", "C"]
def show_room(room):
    picture = ""
    for spot in room:
        if spot == "D":
            picture += "💩"
        else:
            picture += "✨"

    print(picture)
print("Our room right now:")
show_room(room)
def clean_spot(spot):
    if spot == "D":
        return "C"
    else:
        return "C"
result = clean_spot("D")
print("The robot looked at a dirty spot 💩 and made it:", result, "(C means clean ✨)")
print("BEFORE - the dirty room:")
def show_room(room):
    print (room)
for i in range(len(room)):
    room[i] = clean_room(room[i])
print("AFTER cleaning spot number", i + 1, ":")
show_room(room)
print()
print("AFTER - all done! ✨🤖✨")
# Out:
# Hello! I am python.
# Today we will build a cleaning robot together.
# 5 is the answer to 2 + 3
# Our room right now:
# 💩✨💩💩✨
# The robot looked at a dirty spot 💩 and made it: C (C means clean ✨)
# BEFORE - the dirty room:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1124/2843796521.py in <cell line: 0>()
#      25     print (room)
#      26 for i in range(len(room)):
# ---> 27     room[i] = clean_room(room[i])
#      28 print("AFTER cleaning spot number", i + 1, ":")
#      29 show_room(room)
#
# NameError: name 'clean_room' is not defined

# %% [markdown]
# practical 2

# %%
def simple_chatbot():
    print("Hello! I'm a simple chatbot. Type 'quit' to exit.")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'quit':
            print("Chatbot: Goodbye!")
            break
        elif "hello" in user_input.lower() or "hi" in user_input.lower():
            print("Chatbot: Hi there! How can I help you today?")
        elif "how are you" in user_input.lower():
            print("Chatbot: I'm just a program, but I'm functioning well! How about you?")
        elif "name" in user_input.lower():
            print("Chatbot: I don't have a name. You can call me Chatbot.")
        elif "weather" in user_input.lower():
            print("Chatbot: I cannot tell you the weather, as I don't have access to real-time information.")
        else:
            print(f"Chatbot: You said: '{user_input}'. I'm not sure how to respond to that.")

simple_chatbot()
# Out:
# Hello! I'm a simple chatbot. Type 'quit' to exit.
# You: hii
# Chatbot: Hi there! How can I help you today?
# You: i want food
# Chatbot: You said: 'i want food'. I'm not sure how to respond to that.
# You: bye
# Chatbot: You said: 'bye'. I'm not sure how to respond to that.
# You: hello
# Chatbot: Hi there! How can I help you today?
# You: hello pavithra
# Chatbot: Hi there! How can I help you today?
# You: bye
# Chatbot: You said: 'bye'. I'm not sure how to respond to that.

# %% [markdown]
# AI chat box
#
# hello
# hii
# pavithra

# %%
def chatbot():
  print("hello i am Revanth ")

print ("chatbot : hello I am your chatbot.")
print ("Type 'bye' to exit.")
while True :
      user = input("you : ")
      if user == '1' :
        print ("chatbot : I am here to help!")
      elif user == '2' :
        print ("chatbot : I am here to help!")
      elif user == '3' :
        print ("chatbot : I am here to help!")
      else:
        print ("good bye")
# Out:
# chatbot : hello I am your chatbot.
# Type 'bye' to exit.

# %% [markdown]
# PRACTICAL 2

# %%
map_rooms ={
"A" :["B" , "c"],
"B" :["D"],
"c" :["D"],
"D" :["G"],
"G" :[],
}
print("Our map:")
print("             A (start)"               )
print("            /  \\" )
print("            B   C    ")
print("            \\   /      ")
print("               D")
print("               -")
print("                G (True sure )")

print("Doors from each room;", map_rooms)
# Out:
# Our map:
#              A (start)
#             /  \
#             B   C
#             \   /
#                D
#                -
#                 G (True sure )
# Doors from each room; {'A': ['B', 'c'], 'B': ['D'], 'c': ['D'], 'D': ['G'], 'G': []}

# %%
def bfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop(0)
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_rooms[room]:
            to_do.append(neighbour)
    return order
order = bfs("A","G")
print("BFS order:", order)
# Out:
# BFS order: ['A', 'B', 'c', 'D', 'G']

# %%
def dfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop()
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_rooms[room]:
            to_do.append(neighbour)
    return order
order = dfs("A","G")
print("DFS order:", order)
# Out:
# DFS order: ['A', 'c', 'D', 'G']

# %%
map_rooms ={
"A" :["B" , "c"],
"B" :["D"],
"c" :["D"],
"D" :["G"],
"G" :[],
}

def dfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop()
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_rooms[room]:
            to_do.append(neighbour)
    return order

door_cost = {
    ("A", "B"): 1,
    ("A", "C"): 1,
    ("B", "D"): 1,
    ("C", "D"): 5,
    ("D", "G"): 1,
}


def path_cost(path):
    total = 0
    for i in range(len(path) - 1):
        door = (path[i], path[i + 1])
        total = total + door_cost[door]
    return total

path1 = ["A", "B", "D", "G"]
path2 = ["A", "C", "D", "G"]

print("Path 1 A -> B -> D -> G costs:", path_cost(path1))
print("Path 2 A -> C -> D -> G costs:", path_cost(path2))

cost1 = path_cost(path1)
cost2 = path_cost(path2)


if cost1 < cost2:
    best_path = path1
    best_cost = cost1
else:
    best_path = path2
    best_cost = cost2

print("Path 1 cost:", cost1)
print("Path 2 cost:", cost2)
print("The cheapest path is", best_path, "with cost", best_cost, )

bfs_order = dfs("A", "G")
dfs_order = dfs("A", "G")
# Out:
# Path 1 A -> B -> D -> G costs: 3
# Path 2 A -> C -> D -> G costs: 7
# Path 1 cost: 3
# Path 2 cost: 7
# The cheapest path is ['A', 'B', 'D', 'G'] with cost 3

# %%
door_cost={("A","B"):1,
           ("B","D"):1,
           ("D","G"):1,
           ("A","C"):5,
           ("C","D"):1
          }
def path_cost(path):
    total=0
    for i in range(len(path) - 1):
        door =(path[i],path[i+1])
        total+= door_cost[door]
    return total
path1=["A","B","D","G"]
path2=["A","C","D","G"]
path1_cost=path_cost(path1)
path2_cost=path_cost(path2)
print("cost of path1: " ,path1_cost)
print("cost of path2: " ,path2_cost)
if path1_cost <= path2_cost :
    print("best path: ", path1 , "best cost: ",path1_cost)
else:
     print("best path: ", path2 , "best cost: ",path2_cost)
# Out:
# cost of path1:  3
# cost of path2:  7
# best path:  ['A', 'B', 'D', 'G'] best cost:  3

# %%
map_rooms ={
"A" :["B" , "c"],
"B" :["D"],
"c" :["D"],
"D" :["G"],
"G" :[],
}

def dfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop()
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_rooms[room]:
            to_do.append(neighbour)
    return order

door_cost = {
    ("A", "B"): 1,
    ("A", "C"): 1,
    ("B", "D"): 1,
    ("C", "D"): 5,
    ("D", "G"): 1,
}


def path_cost(path):
    total = 0
    for i in range(len(path) - 1):
        door = (path[i], path[i + 1])
        total = total + door_cost[door]
    return total

path1 = ["A", "B", "D", "G"]
path2 = ["A", "C", "D", "G"]

print("Path 1 A -> B -> D -> G costs:", path_cost(path1))
print("Path 2 A -> C -> D -> G costs:", path_cost(path2))

cost1 = path_cost(path1)
cost2 = path_cost(path2)


if cost1 < cost2:
    best_path = path1
    best_cost = cost1
else:
    best_path = path2
    best_cost = cost2

print("Path 1 cost:", cost1)
print("Path 2 cost:", cost2)
print("The cheapest path is", best_path, "with cost", best_cost, )

bfs_order = dfs("A", "G")
dfs_order = dfs("A", "G")
# Out:
# Path 1 A -> B -> D -> G costs: 3
# Path 2 A -> C -> D -> G costs: 7
# Path 1 cost: 3
# Path 2 cost: 7
# The cheapest path is ['A', 'B', 'D', 'G'] with cost 3
